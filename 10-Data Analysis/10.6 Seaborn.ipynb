# %% [markdown]
# Seaborn

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: C:\Program Files\Python312\python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
# Basic Plotting with Seaborn
tips = sns.load_dataset('tips')
tips # inbuilt datasets are available
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
sns.scatterplot(data=tips,x='total_bill',y='tip')
plt.title('Scatter Plot of total bill vs tip')
plt.show()

# %%
# Line Plot
sns.lineplot(x='size',y='total_bill',data=tips)
plt.title('Line Plot of total bill by size')
plt.show()

# %%
# Categorical Plots
# bar Plot
sns.barplot(x='day',y='total_bill',data=tips)
plt.title('Bar Plot of Total bill by day')
plt.show()

# %%
# Box Plot 
# Box Plot is also an amazing way to seeing outliers.
sns.boxplot(data=tips,x='total_bill',y='day')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
# Violin Plot
# to see the distribution of the data
sns.violinplot(data=tips,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Histogram

sns.histplot(tips['total_bill'],bins=10,kde=True)# kde means kernel density estimator -True means that I get the curve.
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# KDE Plot
sns.kdeplot(tips['total_bill'],fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# Pair plot
# to see relationship b/w all the variable to the different -2 variables.
# Numerical variable
sns.pairplot(tips)

# %%
# Heatmap
# to see the correlation b/w all the numerical variables

corr = tips[['total_bill','tip','size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
# Plot total sales by product

# plt.figure(figsize=(10,6))
# sns.barplot(x='product category',y='total_revenue',data=df,estimator=sum)

# estimator : In matplotlib we had to probably apply some aggregate functions
# but in seaborn you have a feature called estimator
